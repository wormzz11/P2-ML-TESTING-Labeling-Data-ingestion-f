# %%
from Labeling_data_ingestion.data_handler.process_data import load_data
import matplotlib
import os
from pathlib import Path
import os
import joblib
current = Path().resolve()

for parent in [current] + list(current.parents):
    if (parent / "Labeling_data_ingestion").exists():
        os.chdir(parent)
        break

# %%
model_transformer = joblib.load("trained_models/transformer_pipeline.rfk")
model_tfidf = joblib.load("trained_models/tfIDF_pipeline.rfk")
